# %%
MAIN_PATH = "C:/Users/lhi30/Haein/2023/YBIGTA/2023-2/DA/Big_Con/Share/"
KEYPOINTS_PATH = MAIN_PATH + "Output_Files/person_keypoints.json"
import json
import numpy as np

# %%
with open(MAIN_PATH + "Data/alphapose_1.json") as json_file:
    raw = json.load(json_file)
raw[0]['keypoints']
# Out:
# [667.5162353515625,
#  416.08062744140625,
#  0.9387374520301819,
#  671.7598266601562,
#  409.7152099609375,
#  0.9048846960067749,
#  665.3944091796875,
#  409.7152099609375,
#  0.9225269556045532,
#  690.85595703125,
#  409.7152099609375,
#  0.8832511305809021,
#  686.6123657226562,
#  407.59344482421875,
#  0.5467183589935303,
#  705.7085571289062,
#  435.1767578125,
#  0.7992647290229797,
#  684.4906005859375,
#  439.42034912109375,
#  0.5941640138626099,
#  665.3944091796875,
#  460.6383056640625,
#  0.5550684928894043,
#  673.881591796875,
#  483.97808837890625,
#  0.7500931620597839,
#  642.0546875,
#  462.7601318359375,
#  0.44220906496047974,
#  637.8110961914062,
#  494.5870361328125,
#  0.5825306177139282,
#  748.1444702148438,
#  522.17041015625,
#  0.6562986969947815,
#  720.5610961914062,
#  522.17041015625,
#  0.48958897590637207,
#  690.85595703125,
#  513.6832275390625,
#  0.9029647707939148,
#  663.2726440429688,
#  517.9268188476562,
#  0.7500692009925842,
# ...

# %%
total = []
for i in raw:
    total.extend(i['keypoints'])

# %%
max(total)
# Out:
# 902.41845703125

# %%
with open (KEYPOINTS_PATH) as json_file:
    data = json.load(json_file)

# %%
total_2 = []
for dic in data['1']:
    if dic == -1:
        continue
    total_2.append(list(dic.values()))
total_2
np_total = np.array(total_2).flatten()
max(np_total)
# Out:
# 698.075439453125

# %%
person_0 = data['0']
person_1 = data['1']
# Out:
# [{'0': [667.5162353515625, 416.08062744140625],
#   '1': [671.7598266601562, 409.7152099609375],
#   '2': [665.3944091796875, 409.7152099609375],
#   '3': [690.85595703125, 409.7152099609375],
#   '4': [686.6123657226562, 407.59344482421875],
#   '5': [705.7085571289062, 435.1767578125],
#   '6': [684.4906005859375, 439.42034912109375],
#   '7': [665.3944091796875, 460.6383056640625],
#   '8': [673.881591796875, 483.97808837890625],
#   '9': [642.0546875, 462.7601318359375],
#   '10': [637.8110961914062, 494.5870361328125],
#   '11': [748.1444702148438, 522.17041015625],
#   '12': [720.5610961914062, 522.17041015625],
#   '13': [690.85595703125, 513.6832275390625],
#   '14': [663.2726440429688, 517.9268188476562],
#   '15': [720.5610961914062, 575.2152709960938],
#   '16': [701.4649658203125, 570.9716796875]},
#  {'0': [666.5376586914062, 412.29742431640625],
#   '1': [670.9494018554688, 407.88568115234375],
#   '2': [666.5376586914062, 407.88568115234375],
# ...

# %%
test = np.arange(64).reshape(2, 32)
i = 15
test[:,2*i:2*i + 2]
# Out:
# array([[30, 31],
#        [62, 63]])

# %%
list(person_0[0].values())
# Out:
# [[667.5162353515625, 416.08062744140625],
#  [671.7598266601562, 409.7152099609375],
#  [665.3944091796875, 409.7152099609375],
#  [690.85595703125, 409.7152099609375],
#  [686.6123657226562, 407.59344482421875],
#  [705.7085571289062, 435.1767578125],
#  [684.4906005859375, 439.42034912109375],
#  [665.3944091796875, 460.6383056640625],
#  [673.881591796875, 483.97808837890625],
#  [642.0546875, 462.7601318359375],
#  [637.8110961914062, 494.5870361328125],
#  [748.1444702148438, 522.17041015625],
#  [720.5610961914062, 522.17041015625],
#  [690.85595703125, 513.6832275390625],
#  [663.2726440429688, 517.9268188476562],
#  [720.5610961914062, 575.2152709960938],
#  [701.4649658203125, 570.9716796875]]

# %%
def dictlist_to_array(dictlist: list) -> np.ndarray:
    num_keypoints = len(dictlist[0].values())
    num_frames = len(dictlist)
    result_array = np.zeros(shape = (num_keypoints, 2 * num_frames))
    for i, keypoint in enumerate(dictlist):
        if(keypoint == -1):
            frame_array = np.zeros(shape = (num_keypoints, 2))
            continue
        frame_array = np.array(list(keypoint.values()))
        print(frame_array.shape)
        result_array[:, 2*i:2*i+2] = frame_array
    return result_array

check = dictlist_to_array(person_0)
check1 = dictlist_to_array(person_1)
# Out:
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# (17, 2)
# ...

# %%
check.dtype
# Out:
# dtype('float64')

# %%
np.max(check)
# Out:
# 881.2706298828125

# %%
check.mean()
# Out:
# 529.291588234144

# %%
from sklearn.preprocessing import StandardScaler
standardizer = StandardScaler()
print(standardizer.fit_transform(check))
# standardizer.fit(check)
# print(standardizer.transform(check))
print(standardizer.fit_transform(check1))

st_0 = standardizer.fit_transform(check)
st_1 = standardizer.fit_transform(check1)
# Out:
# [[-0.60916106 -1.04554739 -0.79382995 ... -1.03760015 -0.50274766
#   -0.95576649]
#  [-0.45687067 -1.16121591 -0.6240803  ... -1.11341013 -0.24375818
#   -1.02862756]
#  [-0.68530736 -1.16121591 -0.79382995 ... -1.11327408 -0.76174124
#   -1.0650581 ]
#  ...
#  [-0.76145146  0.80514005 -0.79382995 ...  1.02623325 -1.1502275
#    1.23006737]
#  [ 1.29446777  1.84615118  1.32804307 ...  1.83393634  1.05120151
#    1.84938676]
#  [ 0.60916209  1.7690392   0.56416962 ...  1.69677912  0.27422487
#    1.885817  ]]
# [[-1.40514848 -0.61916757 -1.21901693 ... -1.10347326 -0.34265129
#   -1.0739159 ]
#  [-1.45292363 -0.73526175 -1.31385987 ... -1.13776748 -0.15474586
#   -1.14242105]
#  [ 0.55362868 -1.19963749 -1.2664381  ... -1.13776748 -0.436604
#   -1.14242105]
#  ...
#  [ 0.88805417  0.8126577   0.96238097 ...  1.15995797  0.03315988
#    1.15249518]
#  [-0.35409747  2.20578491 -0.22316093 ...  1.88014068  0.40897075
#    1.87179738]
# ...

# %%
np.concatenate((st_0, st_1), axis = 0).shape
# Out:
# (34, 974)
